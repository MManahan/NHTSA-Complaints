# %%
import pandas as pd
import duckdb

# %%
con = duckdb.connect(database='NHTSA.duckdb')

# %%
query = """SELECT * FROM read_csv('FLAT_CMPL.txt', delim='\t');"""

# %%
results = duckdb.sql(query).df()

# %%
results.head()
# Out:
#    column00  column01                column02 column03     column04  column05  \
# 0         1    958241      Volvo Car USA, LLC    VOLVO          760      1987
# 1         2    958130      Ford Motor Company     FORD  THUNDERBIRD      1992
# 2         3    958132       Kia America, Inc.      KIA       SEPHIA      1994
# 3         4    958133  Chrysler (FCA US, LLC)    DODGE          600      1987
# 4         5    958137  Chrysler (FCA US, LLC)    DODGE      CARAVAN      1991
#
#   column06  column07 column08  column09  ...  column39 column40 column41  \
# 0        N      <NA>        N         0  ...      None     None     None
# 1        N  19941222        N         0  ...      None     None     None
# 2        Y  19941230        N         0  ...      None     None     None
# 3        N  19941231        N         0  ...      None     None     None
# 4        N  19941218        N         0  ...      None     None     None
#
# ...
